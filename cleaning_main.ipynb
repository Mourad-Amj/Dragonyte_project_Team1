# %%
import pandas as pd

# %%
categories = pd.read_csv("./Data/Categories.csv",index_col="id")
categories
# Out:
#                            Name
# id
# 1                          Beer
# 2                          Wine
# 3                       Spirits
# 4   RTDs/High-Strength Premixes
# 5                   Cider/Perry

# %%
subcategories = pd.read_csv("./Data/Subcategories.csv",index_col="id")
subcategories
# Out:
#     Category                         Name
# id
# 1          1                          Ale
# 2          1  Weissbier/Weizen/Wheat Beer
# 3          1        Flavoured/Mixed Lager
# 4          1               Standard Lager
# 5          1                      Sorghum
# 6          1                        Stout
# 7          1           Non Alcoholic Beer
# 8          1                        Lager
# 9          1                    Dark Beer
# 10         1                Premium Lager
# 11         1             Mid-Priced Lager
# 12         1                Economy Lager
# 13         1                         Beer
# 14         2                         Wine
# 15         3                      Spirits
# 16         4  RTDs/High-Strength Premixes
# 17         5                  Cider/Perry

# %%
locations = pd.read_csv("./Data/Locations.csv", delimiter=";")
locations = locations.T.dropna()
locations.columns = locations.iloc[0]
locations = locations.tail(-1)

# %%
locations["Region"]
# Out:
# 1              Asia Pacific
# 2               Australasia
# 3            Eastern Europe
# 4             Latin America
# 5    Middle East and Africa
# 6             North America
# 7            Western Europe
# 8                     World
# Name: Region, dtype: object

# %% [markdown]
# # CHANNEL VOLUME DATA

# %%
channel_volume = pd.read_csv("./Data/Channel_Volume.csv")

# %%
channel_volume["Subcategory"].unique()
# Out:
# array(['Beer', 'Cider/Perry', 'RTDs/High-Strength Premixes', 'Spirits',
#        'Wine'], dtype=object)

# %%
mapping_location = {1.0:'Asia Pacific', 2.0:'Australasia', 3.0:'Eastern Europe', 4.0:'Latin America', 5.0:'Middle East and Africa', 6.0:'North America', 7.0:'Western Europe', 8.0:'World'}
channel_volume['Location'].replace(mapping_location, inplace=True)

# %%
channel_volume['Year_date'] = pd.to_datetime(channel_volume['Year_date'])
channel_volume['Year_date'] = channel_volume['Year_date'].dt.strftime("%d/%m/%Y")

# %%
channel_volume.loc[(channel_volume["Category"].isna() == True) & (channel_volume["Subcategory"] == "Wine"), "Category"] = "Wine"
channel_volume.loc[(channel_volume["Category"].isna() == True) & (channel_volume["Subcategory"]== "Beer"), "Category"] = "Beer"
channel_volume.loc[(channel_volume["Category"].isna() == True) & (channel_volume["Subcategory"]== "Cider/Perry"), "Category"] = "Cider/Perry"

# %%
channel_volume['Volume'] = channel_volume['Volume'].str.replace(',', '.').astype(float)

# %%
channel_volume.loc[(channel_volume["Outlet"] == "VEnding"), "Outlet"] = "Vending"

# %%
channel_volume.loc[channel_volume["Unit"]=='000 litres',"Volume_liters"] = channel_volume["Volume"] * 1000.0
channel_volume.loc[channel_volume["Unit"]=='million litres',"Volume_liters"] = channel_volume["Volume"] * 1000000.0

# %%
channel_volume.to_csv("./clean_data/channel_volume.csv")

# %%
channel_volume
# Out:
#             Location          Industry  Edition Category Subcategory  \
# 0       Asia Pacific  Alcoholic Drinks     2022     Beer        Beer
# 1       Asia Pacific  Alcoholic Drinks     2022     Beer        Beer
# 2       Asia Pacific  Alcoholic Drinks     2022     Beer        Beer
# 3       Asia Pacific  Alcoholic Drinks     2022     Beer        Beer
# 4       Asia Pacific  Alcoholic Drinks     2022     Beer        Beer
# ...              ...               ...      ...      ...         ...
# 8463  Western Europe  Alcoholic Drinks     2022     Beer        Beer
# 8464  Western Europe  Alcoholic Drinks     2022     Beer        Beer
# 8465  Western Europe  Alcoholic Drinks     2022     Beer        Beer
# 8466  Western Europe  Alcoholic Drinks     2022     Beer        Beer
# 8467  Western Europe  Alcoholic Drinks     2022     Beer        Beer
#
#       Hierarchy_Level         Data_Type                          Outlet  \
# 0                   1  Off-trade Volume  Food/drink/tobacco specialists
# 1                   1  Off-trade Volume  Food/drink/tobacco specialists
# 2                   1  Off-trade Volume  Food/drink/tobacco specialists
# 3                   1  Off-trade Volume  Food/drink/tobacco specialists
# 4                   1  Off-trade Volume  Food/drink/tobacco specialists
# ...               ...               ...                             ...
# 8463                1  Off-trade Volume           Store-Based Retailing
# 8464                1  Off-trade Volume           Store-Based Retailing
# 8465                1  Off-trade Volume           Store-Based Retailing
# 8466                1  Off-trade Volume           Store-Based Retailing
# 8467                1  Off-trade Volume           Store-Based Retailing
#
#       Outlet_Hierarchy            Unit  Year_text   Year_date        Volume  \
# 0                    3  million litres       2007  31/12/2007   2613.845506
# 1                    3  million litres       2008  31/12/2008   2513.025824
# 2                    3  million litres       2009  31/12/2009   2421.088595
# 3                    3  million litres       2010  31/12/2010   2422.128432
# 4                    3  million litres       2011  31/12/2011   2439.336220
# ...                ...             ...        ...         ...           ...
# 8463                 1  million litres       2017  31/12/2017  16514.210840
# 8464                 1  million litres       2018  31/12/2018  16522.152390
# 8465                 1  million litres       2019  31/12/2019  16544.606440
# 8466                 1  million litres       2020  31/12/2020  16626.514900
# 8467                 1  million litres       2021  31/12/2021  16664.638000
#
#       Volume_liters
# 0      2.613846e+09
# 1      2.513026e+09
# 2      2.421089e+09
# 3      2.422128e+09
# 4      2.439336e+09
# ...             ...
# 8463   1.651421e+10
# 8464   1.652215e+10
# 8465   1.654461e+10
# 8466   1.662651e+10
# 8467   1.666464e+10
#
# [8468 rows x 14 columns]

# %% [markdown]
# # COMPANY SHARE DATA

# %%
company_share = pd.read_csv("./Data/Company_Share_GBO_unit.csv", delimiter=";")
company_share = company_share.dropna(ignore_index=True)

# %%
company_share['Volume'] = company_share['Volume'].str.replace(',', '.').astype(float)

# %%
mapping_location = {1.0:'Asia Pacific', 2.0:'Australasia', 3.0:'Eastern Europe', 4.0:'Latin America', 5.0:'Middle East and Africa', 6.0:'North America', 7.0:'Western Europe', 8.0:'World'}
company_share['Location'].replace(mapping_location,inplace=True)

# %%
subcategories_mapping = subcategories["Name"].to_dict()
company_share['Subcategory_ID'].replace(subcategories_mapping,inplace=True)
company_share = company_share.rename(columns={"Subcategory_ID": "Subcategory"})

# %%
company_share['Year_date'] = pd.to_datetime(company_share['Year_date'], format='mixed', dayfirst=True)
company_share['Year_date'] = company_share['Year_date'].dt.strftime("%d/%m/%Y")

# %%
company_share.loc[company_share["Unit"]=='000 litres',"Volume_liters"] = company_share["Volume"] * 1000.0
company_share.loc[company_share["Unit"]=='million litres',"Volume_liters"] = company_share["Volume"] * 1000000.0

# %%
company_share["Non_minus_year"] = (company_share["Year_minus_2016"] + 2016)

# %%
company_share.to_csv("./clean_data/company_share.csv")

# %%
company_share
# Out:
#       Location          Industry Subcategory  Hierarchy_Level     Data_Type  \
# 0        World  Alcoholic Drinks        Beer              1.0  Total Volume
# 1        World  Alcoholic Drinks        Beer              1.0  Total Volume
# 2        World  Alcoholic Drinks        Beer              1.0  Total Volume
# 3        World  Alcoholic Drinks        Beer              1.0  Total Volume
# 4        World  Alcoholic Drinks        Beer              1.0  Total Volume
# ...        ...               ...         ...              ...           ...
# 21663    World  Alcoholic Drinks     Spirits              1.0  Total Volume
# 21664    World  Alcoholic Drinks     Spirits              1.0  Total Volume
# 21665    World  Alcoholic Drinks     Spirits              1.0  Total Volume
# 21666    World  Alcoholic Drinks     Spirits              1.0  Total Volume
# 21667    World  Alcoholic Drinks     Spirits              1.0  Total Volume
#
#                               Global_Brand_Owner            Unit  Year_text  \
# 0                        Anheuser-Busch InBev NV  million litres     2016.0
# 1                                    Heineken NV  million litres     2016.0
# 2                                  Carlsberg A/S  million litres     2016.0
# 3                              Dragonyte Brewery  million litres     2016.0
# 4                        Tsingtao Brewery Co Ltd  million litres     2016.0
# ...                                          ...             ...        ...
# 21663  Central European Distribution Corp (CEDC)      000 litres     2016.0
# 21664           Hubei Zhijiang Distillery Co Ltd      000 litres     2016.0
# 21665                          Rosspirtprom FGUP      000 litres     2016.0
# 21666                              Private Label      000 litres     2016.0
# 21667                                     Others      000 litres     2016.0
#
#         Year_date  Year_minus_2016        Volume  Volume_liters  \
# 0      31/12/2016              4.0  35506.377320   3.550638e+10
# 1      31/12/2016              4.0  18482.595800   1.848260e+10
# 2      31/12/2016              4.0  11121.698680   1.112170e+10
# 3      31/12/2016              4.0   6252.382590   6.252383e+09
# 4      31/12/2016              4.0   7834.494901   7.834495e+09
# ...           ...              ...           ...            ...
# 21663  31/12/2016              4.0    223.024726   2.230247e+05
# 21664  31/12/2016              4.0     78.555881   7.855588e+04
# 21665  31/12/2016              4.0      3.708014   3.708014e+03
# 21666  31/12/2016              4.0    307.766367   3.077664e+05
# 21667  31/12/2016              4.0   8263.549123   8.263549e+06
#
#        Non_minus_year
# 0              2020.0
# 1              2020.0
# 2              2020.0
# 3              2020.0
# 4              2020.0
# ...               ...
# 21663          2020.0
# 21664          2020.0
# 21665          2020.0
# 21666          2020.0
# 21667          2020.0
#
# [21668 rows x 13 columns]

# %% [markdown]
# # MARKET SIZE DATA

# %%
market_size = pd.read_csv("./Data/Market_Sizes.csv")

# %%
# market_size["RSP"] = (market_size["RSP"]*1000).astype(int)

# %%
market_size['Year_date'] = pd.to_datetime(market_size['Year_date'], format='mixed', dayfirst=True)
market_size['Year_date'] = market_size['Year_date'].dt.strftime('%d/%m/%Y')

# %%
mapping_location = {1.0:'Asia Pacific', 2.0:'Australasia', 3.0:'Eastern Europe', 4.0:'Latin America', 5.0:'Middle East and Africa', 6.0:'North America', 7.0:'Western Europe', 8.0:'World'}
market_size['Location'].replace(mapping_location,inplace=True)

# %%
market_size["Non_minus_year"] = market_size["Year_minus_2016"] + 2016

# %%
subcategories_mapping = subcategories["Name"].to_dict()
market_size['Subcategory'].replace(subcategories_mapping,inplace=True)

# %%
for index,value in market_size["Volume"].items():
    if int(str(value).split(".")[1]) > 0:
        market_size.loc[index,"Volume"] = value*1000.0

# %%
market_size
# Out:
#             Location          Industry  Subcategory  Hierarchy_Level  \
# 0       Asia Pacific  Alcoholic Drinks          Ale                3
# 1       Asia Pacific  Alcoholic Drinks          Ale                3
# 2       Asia Pacific  Alcoholic Drinks          Ale                3
# 3       Asia Pacific  Alcoholic Drinks          Ale                3
# 4       Asia Pacific  Alcoholic Drinks          Ale                3
# ...              ...               ...          ...              ...
# 1216  Western Europe  Alcoholic Drinks  Cider/Perry                1
# 1217  Western Europe  Alcoholic Drinks  Cider/Perry                1
# 1218  Western Europe  Alcoholic Drinks  Cider/Perry                1
# 1219  Western Europe  Alcoholic Drinks  Cider/Perry                1
# 1220  Western Europe  Alcoholic Drinks  Cider/Perry                1
#
#             Data_Type         Unit  \
# 0     Total Value RSP  USD million
# 1     Total Value RSP  USD million
# 2     Total Value RSP  USD million
# 3     Total Value RSP  USD million
# 4     Total Value RSP  USD million
# ...               ...          ...
# 1216  Total Value RSP  USD million
# 1217  Total Value RSP  USD million
# 1218  Total Value RSP  USD million
# 1219  Total Value RSP  USD million
# 1220  Total Value RSP  USD million
#
#                                        Current_Constant  \
# 0     Historic Constant 2021 Prices, Forecast Consta...
# 1     Historic Constant 2021 Prices, Forecast Consta...
# 2     Historic Constant 2021 Prices, Forecast Consta...
# 3     Historic Constant 2021 Prices, Forecast Consta...
# 4     Historic Constant 2021 Prices, Forecast Consta...
# ...                                                 ...
# 1216  Historic Constant 2021 Prices, Forecast Consta...
# 1217  Historic Constant 2021 Prices, Forecast Consta...
# 1218  Historic Constant 2021 Prices, Forecast Consta...
# 1219  Historic Constant 2021 Prices, Forecast Consta...
# 1220  Historic Constant 2021 Prices, Forecast Consta...
#
#                                     Currency_Conversion  Year   Year_date  \
# 0     Historic Fixed 2021 Exchange Rates, Forecast F...  2016  31/12/2016
# 1     Historic Fixed 2021 Exchange Rates, Forecast F...  2017  31/12/2017
# 2     Historic Fixed 2021 Exchange Rates, Forecast F...  2018  31/12/2018
# 3     Historic Fixed 2021 Exchange Rates, Forecast F...  2019  31/12/2019
# 4     Historic Fixed 2021 Exchange Rates, Forecast F...  2020  31/12/2020
# ...                                                 ...   ...         ...
# 1216  Historic Fixed 2021 Exchange Rates, Forecast F...  2022  31/12/2022
# 1217  Historic Fixed 2021 Exchange Rates, Forecast F...  2023  31/12/2023
# 1218  Historic Fixed 2021 Exchange Rates, Forecast F...  2024  31/12/2024
# 1219  Historic Fixed 2021 Exchange Rates, Forecast F...  2025  31/12/2025
# 1220  Historic Fixed 2021 Exchange Rates, Forecast F...  2026  31/12/2026
#
#           RSP  Volume  Year_minus_2016  Year_minus_2022  Edition  \
# 0     301.000    27.0                4               -2     2022
# 1     318.000    28.0                5               -1     2022
# 2     458.000    40.0                6                0     2022
# 3     612.000    51.0                7                1     2022
# 4     774.000    62.0                8                2     2022
# ...       ...     ...              ...              ...      ...
# 1216    6.545  1204.0               10                4     2022
# 1217    6.628  1214.0               11                5     2022
# 1218    6.708  1227.0               12                6     2022
# 1219    6.793  1240.0               13                7     2022
# 1220    6.892  1256.0               14                8     2022
#
#       Non_minus_year
# 0               2020
# 1               2021
# 2               2022
# 3               2023
# 4               2024
# ...              ...
# 1216            2026
# 1217            2027
# 1218            2028
# 1219            2029
# 1220            2030
#
# [1221 rows x 16 columns]

# %%
for index,value in market_size["RSP"].items():
    if int(str(value).split(".")[1]) > 0:
        market_size.loc[index,"RSP"] = value*1000.0

# %%
market_size["Price_per_unit"] = market_size["RSP"]/market_size["Volume"]

# %%
market_size
# Out:
#             Location          Industry  Subcategory  Hierarchy_Level  \
# 0       Asia Pacific  Alcoholic Drinks          Ale                3
# 1       Asia Pacific  Alcoholic Drinks          Ale                3
# 2       Asia Pacific  Alcoholic Drinks          Ale                3
# 3       Asia Pacific  Alcoholic Drinks          Ale                3
# 4       Asia Pacific  Alcoholic Drinks          Ale                3
# ...              ...               ...          ...              ...
# 1216  Western Europe  Alcoholic Drinks  Cider/Perry                1
# 1217  Western Europe  Alcoholic Drinks  Cider/Perry                1
# 1218  Western Europe  Alcoholic Drinks  Cider/Perry                1
# 1219  Western Europe  Alcoholic Drinks  Cider/Perry                1
# 1220  Western Europe  Alcoholic Drinks  Cider/Perry                1
#
#             Data_Type         Unit  \
# 0     Total Value RSP  USD million
# 1     Total Value RSP  USD million
# 2     Total Value RSP  USD million
# 3     Total Value RSP  USD million
# 4     Total Value RSP  USD million
# ...               ...          ...
# 1216  Total Value RSP  USD million
# 1217  Total Value RSP  USD million
# 1218  Total Value RSP  USD million
# 1219  Total Value RSP  USD million
# 1220  Total Value RSP  USD million
#
#                                        Current_Constant  \
# 0     Historic Constant 2021 Prices, Forecast Consta...
# 1     Historic Constant 2021 Prices, Forecast Consta...
# 2     Historic Constant 2021 Prices, Forecast Consta...
# 3     Historic Constant 2021 Prices, Forecast Consta...
# 4     Historic Constant 2021 Prices, Forecast Consta...
# ...                                                 ...
# 1216  Historic Constant 2021 Prices, Forecast Consta...
# 1217  Historic Constant 2021 Prices, Forecast Consta...
# 1218  Historic Constant 2021 Prices, Forecast Consta...
# 1219  Historic Constant 2021 Prices, Forecast Consta...
# 1220  Historic Constant 2021 Prices, Forecast Consta...
#
#                                     Currency_Conversion  Year   Year_date  \
# 0     Historic Fixed 2021 Exchange Rates, Forecast F...  2016  31/12/2016
# 1     Historic Fixed 2021 Exchange Rates, Forecast F...  2017  31/12/2017
# 2     Historic Fixed 2021 Exchange Rates, Forecast F...  2018  31/12/2018
# 3     Historic Fixed 2021 Exchange Rates, Forecast F...  2019  31/12/2019
# 4     Historic Fixed 2021 Exchange Rates, Forecast F...  2020  31/12/2020
# ...                                                 ...   ...         ...
# 1216  Historic Fixed 2021 Exchange Rates, Forecast F...  2022  31/12/2022
# 1217  Historic Fixed 2021 Exchange Rates, Forecast F...  2023  31/12/2023
# 1218  Historic Fixed 2021 Exchange Rates, Forecast F...  2024  31/12/2024
# 1219  Historic Fixed 2021 Exchange Rates, Forecast F...  2025  31/12/2025
# 1220  Historic Fixed 2021 Exchange Rates, Forecast F...  2026  31/12/2026
#
#          RSP  Volume  Year_minus_2016  Year_minus_2022  Edition  \
# 0      301.0    27.0                4               -2     2022
# 1      318.0    28.0                5               -1     2022
# 2      458.0    40.0                6                0     2022
# 3      612.0    51.0                7                1     2022
# 4      774.0    62.0                8                2     2022
# ...      ...     ...              ...              ...      ...
# 1216  6545.0  1204.0               10                4     2022
# 1217  6628.0  1214.0               11                5     2022
# 1218  6708.0  1227.0               12                6     2022
# 1219  6793.0  1240.0               13                7     2022
# 1220  6892.0  1256.0               14                8     2022
#
#       Non_minus_year  Price_per_unit
# 0               2020       11.148148
# 1               2021       11.357143
# 2               2022       11.450000
# 3               2023       12.000000
# 4               2024       12.483871
# ...              ...             ...
# 1216            2026        5.436047
# 1217            2027        5.459638
# 1218            2028        5.466993
# 1219            2029        5.478226
# 1220            2030        5.487261
#
# [1221 rows x 17 columns]

# %%
market_size.to_csv("./clean_data/market_size.csv")
