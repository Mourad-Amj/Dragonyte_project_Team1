# %%
import pandas as pd

# %%
filepath = './clean_data/Market_Sizes.csv'

marketdata = pd.read_csv(filepath)

# Print the first few rows of the DataFrame
print(marketdata.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 filepath = './clean_data/Market_Sizes.csv'
# ----> 3 marketdata = pd.read_csv(filepath)
#       5 # Print the first few rows of the DataFrame
#       6 print(marketdata.head())
#
# NameError: name 'pd' is not defined

# %%
print(marketdata.columns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(marketdata.columns)
#
# NameError: name 'marketdata' is not defined

# %%
num_rows_before = marketdata.shape[0]
df_dropped = marketdata.dropna()
num_rows_after = df_dropped.shape[0]
num_rows_dropped = num_rows_before - num_rows_after

print(f'Number of rows dropped: {num_rows_dropped}')

# %%
print(marketdata)

# %%
marketdata['Year_date'] = pd.to_datetime(marketdata['Year_date'], format='%d/%m/%Y', errors='coerce')
num_invalid_dates = marketdata['Year_date'].isna().sum()
print(f'Number of invalid dates: {num_invalid_dates}')

# %%
unique_units = marketdata['Unit'].unique()
print(unique_units)

# %%
import csv

data = """
Afghanistan,Asia,South Asia
Albania,Europe,Central and Eastern Europe
Algeria,Middle East and North Africa,North Africa
...
Zimbabwe,Sub-Saharan Africa,Southern Africa
"""

# Split the data into lines, then split each line on comma
data = [line.split(',') for line in data.split('\n') if line]

with open('countries.csv', 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(['Country', 'Region', 'Subregion'])  # Write the header
    writer.writerows(data)  # Write the data

# %%
import csv

data = """
Afghanistan	Asia	South Asia
Albania	Europe	Central and Eastern Europe
Algeria	Middle East and North Africa	North Africa
Andorra	Europe	Western Europe
Angola	Sub-Saharan Africa	Southern Africa
Antigua and Barbuda	Americas	Caribbean
Argentina	Americas	South America
Armenia	Europe	Central and Eastern Europe
Australia	Pacific	Australia and New Zealand
Austria	Europe	Western Europe
Azerbaijan	Europe	Central and Eastern Europe
Bahamas	Americas	Caribbean
Bahrain	Middle East and North Africa	Middle East
Bangladesh	Asia	South Asia
Barbados	Americas	Caribbean
Belarus	Europe	Central and Eastern Europe
Belgium	Europe	Western Europe
Belize	Americas	Central America
Benin	Sub-Saharan Africa	West Africa
Bhutan	Asia	South Asia
Bolivia (Plurinational State of)	Americas	South America
Bosnia and Herzegovina	Europe	Central and Eastern Europe
Botswana	Sub-Saharan Africa	Southern Africa
Brazil	Americas	South America
Brunei Darussalam	Asia	South East Asia
Bulgaria	Europe	Central and Eastern Europe
Burkina Faso	Sub-Saharan Africa	West Africa
Burundi	Sub-Saharan Africa	Central Africa
Cabo Verde	Sub-Saharan Africa	West Africa
Cambodia	Asia	South East Asia
Cameroon	Sub-Saharan Africa	Central Africa
Canada	Americas	North America
Central African Republic	Sub-Saharan Africa	Central Africa
Chad	Sub-Saharan Africa	Central Africa
Chile	Americas	South America
China	Asia	East Asia
Colombia	Americas	South America
Comoros	Sub-Saharan Africa	East Africa
Congo	Sub-Saharan Africa	Central Africa
Costa Rica	Americas	Central America
Croatia	Europe	Central and Eastern Europe
Cuba	Americas	Caribbean
Cyprus	Europe	Southern Europe
Czech Republic	Europe	Central and Eastern Europe
Côte d'Ivoire	Sub-Saharan Africa	West Africa
Democratic People's Republic of Korea	Asia	East Asia
Democratic Republic of the Congo	Sub-Saharan Africa	Central Africa
Denmark	Europe	Nordic countries
Djibouti	Sub-Saharan Africa	East Africa
Dominica	Americas	Caribbean
Dominican Republic	Americas	Caribbean
Ecuador	Americas	South America
Egypt	Middle East and North Africa	Middle East
El Salvador	Americas	Central America
Equatorial Guinea	Sub-Saharan Africa	Central Africa
Eritrea	Sub-Saharan Africa	East Africa
Estonia	Europe	Central and Eastern Europe
Eswatini	Sub-Saharan Africa	Southern Africa
Ethiopia	Sub-Saharan Africa	East Africa
Fiji	Pacific	Pacific Islands
Finland	Europe	Nordic countries
France	Europe	Western Europe
Gabon	Sub-Saharan Africa	Central Africa
Gambia (The)	Sub-Saharan Africa	West Africa
Georgia	Europe	Central and Eastern Europe
Germany	Europe	Western Europe
Ghana	Sub-Saharan Africa	West Africa
Greece	Europe	Southern Europe
Grenada	Americas	Caribbean
Guatemala	Americas	Central America
Guinea	Sub-Saharan Africa	West Africa
Guinea-Bissau	Sub-Saharan Africa	West Africa
Guyana	Americas	South America
Haiti	Americas	Caribbean
Honduras	Americas	Central America
Hungary	Europe	Central and Eastern Europe
Iceland	Europe	Nordic countries
India	Asia	South Asia
Indonesia	Asia	South East Asia
Iran (Islamic Republic of)	Asia	South Asia
Iraq	Middle East and North Africa	Middle East
Ireland	Europe	Western Europe
Israel	Middle East and North Africa	Middle East
Italy	Europe	Southern Europe
Jamaica	Americas	Caribbean
Japan	Asia	East Asia
Jordan	Middle East and North Africa	Middle East
Kazakhstan	Asia	Central Asia
Kenya	Sub-Saharan Africa	East Africa
Kiribati	Pacific	Pacific Islands
Kuwait	Middle East and North Africa	Middle East
Kyrgyzstan	Asia	Central Asia
Lao People's Democratic Republic	Asia	South East Asia
Latvia	Europe	Central and Eastern Europe
Lebanon	Middle East and North Africa	Middle East
Lesotho	Sub-Saharan Africa	Southern Africa
Liberia	Sub-Saharan Africa	West Africa
Libya	Middle East and North Africa	North Africa
Liechtenstein	Europe	Western Europe
Lithuania	Europe	Central and Eastern Europe
Luxembourg	Europe	Western Europe
Madagascar	Sub-Saharan Africa	Southern Africa
Malawi	Sub-Saharan Africa	Southern Africa
Malaysia	Asia	South East Asia
Maldives	Asia	South Asia
Mali	Sub-Saharan Africa	West Africa
Malta	Europe	Southern Europe
Marshall Islands	Pacific	Pacific Islands
Mauritania	Middle East and North Africa	North Africa
Mauritius	Sub-Saharan Africa	Southern Africa
Mexico	Americas	North America
Micronesia (Federated States of)	Pacific	Pacific Islands
Monaco	Europe	Western Europe
Mongolia	Asia	East Asia
Montenegro	Europe	Central and Eastern Europe
Morocco	Middle East and North Africa	North Africa
Mozambique	Sub-Saharan Africa	Southern Africa
Myanmar	Asia	South East Asia
Namibia	Sub-Saharan Africa	Southern Africa
Nauru	Pacific	Pacific Islands
Nepal	Asia	South Asia
Netherlands	Europe	Western Europe
New Zealand	Pacific	Australia and New Zealand
Nicaragua	Americas	Central America
Niger	Sub-Saharan Africa	West Africa
Nigeria	Sub-Saharan Africa	West Africa
North Macedonia	Europe	Central and Eastern Europe
Norway	Europe	Nordic countries
Oman	Middle East and North Africa	Middle East
Pakistan	Asia	South Asia
Palau	Pacific	Pacific Islands
Panama	Americas	Central America
Papua New Guinea	Pacific	Pacific Islands
Paraguay	Americas	South America
Peru	Americas	South America
Philippines	Asia	South East Asia
Poland	Europe	Central and Eastern Europe
Portugal	Europe	Southern Europe
Qatar	Middle East and North Africa	Middle East
Republic of Korea	Asia	East Asia
Republic of Moldova	Europe	Central and Eastern Europe
Romania	Europe	Central and Eastern Europe
Russian Federation	Europe	Central and Eastern Europe
Rwanda	Sub-Saharan Africa	Central Africa
Saint Kitts and Nevis	Americas	Caribbean
Saint Lucia	Americas	Caribbean
Saint Vincent and the Grenadines	Americas	Caribbean
Samoa	Pacific	Pacific Islands
San Marino	Europe	Southern Europe
Sao Tome and Principe	Sub-Saharan Africa	Central Africa
Saudi Arabia	Middle East and North Africa	Middle East
Senegal	Sub-Saharan Africa	West Africa
Serbia	Europe	Central and Eastern Europe
Seychelles	Sub-Saharan Africa	Southern Africa
Sierra Leone	Sub-Saharan Africa	West Africa
Singapore	Asia	South East Asia
Slovakia	Europe	Central and Eastern Europe
Slovenia	Europe	Central and Eastern Europe
Solomon Islands	Pacific	Pacific Islands
Somalia	Sub-Saharan Africa	East Africa
South Africa	Sub-Saharan Africa	Southern Africa
South Sudan	Sub-Saharan Africa	East Africa
Spain	Europe	Southern Europe
Sri Lanka	Asia	South Asia
Sudan	Middle East and North Africa	North Africa
Suriname	Americas	South America
Sweden	Europe	Nordic countries
Switzerland	Europe	Western Europe
Syrian Arab Republic	Middle East and North Africa	Middle East
Tajikistan	Asia	Central Asia
Thailand	Asia	South East Asia
Timor-Leste	Asia	South East Asia
Togo	Sub-Saharan Africa	West Africa
Tonga	Pacific	Pacific Islands
Trinidad and Tobago	Americas	Caribbean
Tunisia	Middle East and North Africa	North Africa
Turkmenistan	Asia	Central Asia
Tuvalu	Pacific	Pacific Islands
Türkiye	Europe	Southern Europe
Uganda	Sub-Saharan Africa	East Africa
Ukraine	Europe	Central and Eastern Europe
United Arab Emirates	Middle East and North Africa	Middle East
United Kingdom	Europe	Western Europe
United Republic of Tanzania	Sub-Saharan Africa	East Africa
United States of America	Americas	North America
Uruguay	Americas	South America
Uzbekistan	Asia	Central Asia
Vanuatu	Pacific	Pacific Islands
Venezuela (Bolivarian Republic of)	Americas	South America
Viet Nam	Asia	South East Asia
Yemen	Middle East and North Africa	Middle East
Zambia	Sub-Saharan Africa	Southern Africa
Zimbabwe	Sub-Saharan Africa	Southern Africa
"""

region_map = {
    'Asia': 'Asia Pacific',
    'Pacific': 'Australasia',
    'Europe': 'Eastern Europe',
    'Americas': 'Latin America',
    'Middle East and North Africa': 'Middle East and Africa',
    'Sub-Saharan Africa': 'Middle East and Africa',
    'Americas': 'North America',
    'Europe': 'Western Europe'
}

# Split the data into lines, then split each line on comma
data = [line.split(',') for line in data.split('\n') if line]

# Replace old region with new region
for row in data:
    old_region = row[1]
    if old_region in region_map:
        row[1] = region_map[old_region]

with open('countries.csv', 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(['Country', 'Region', 'Subregion'])  # Write the header
    writer.writerows(data)  # Write the data

# %%
import csv

country_region_map = {
    'North America': ['Canada', 'United States'],
    'Western Europe': ['Britain', 'France', 'Germany', 'Italy', 'Spain'],
    'Eastern Europe': ['Greece', 'Poland', 'Czech Republic', 'Russia'],
    'Middle East and Africa': ['Turkey', 'Egypt', 'Jordan', 'Lebanon', 'Palestinian territories', 'Tunisia', 'Israel'],
    'Asia Pacific': ['Australia', 'China', 'Indonesia', 'Japan', 'Malaysia', 'Pakistan', 'Philippines', 'South Korea'],
    'Latin America': ['Argentina', 'Bolivia', 'Brazil', 'Chile', 'El Salvador', 'Mexico', 'Venezuela'],
}

region_country_map = {country: region for region, countries in country_region_map.items() for country in countries}

data = list(region_country_map.items())

with open('./clean_data/countries.csv', 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(['Country', 'Region'])
    writer.writerows(data)

# %%
import os

if not os.path.exists('./clean_data/'):
    os.makedirs('./clean_data/')

# %%
mapfilepath = './clean_data/Custom-Regions.csv'

mapdata = pd.read_csv(mapfilepath)


# print(mapdata)

print(mapdata["Region"].unique())
# Out:
# ['Balkans' 'Central Asia' 'North Africa' nan 'Southern Europe'
#  'Central Africa' 'Caribbean' 'Latin America' 'Transcaucasia'
#  'Australasia' 'Western Europe' 'Middle East' 'South Asia'
#  'Eastern Europe' 'West Africa' 'Southern Africa' 'SouthEast Asia'
#  'East Africa' 'USA/Canada' 'Far East' 'Northern Europe' 'Melanesia'
#  'Micronesia' 'Polynesia']

# %%
print(mapdata.columns)
# Out:
# Index(['Country', 'Continent', 'Region'], dtype='object')

# %%
country_region_map = {
    'North America': ['USA/Canada'],
    'Western Europe': ['Western Europe', 'Southern Europe', 'Northern Europe'],
    'Eastern Europe': ['Eastern Europe', 'Balkans', 'Transcaucasia'],
    'Middle East and Africa': ['North Africa', 'Central Africa', 'West Africa', 'Southern Africa', 'East Africa', 'Middle East'],
    'Asia Pacific': ['Central Asia', 'South Asia', 'SouthEast Asia', 'Far East', 'Australasia', 'Melanesia', 'Micronesia', 'Polynesia'],
    'Latin America': ['Latin America', 'Caribbean'],
    'World': ['USA/Canada', 'Western Europe', 'Southern Europe', 'Northern Europe', 'Eastern Europe', 'Balkans', 'Transcaucasia', 'North Africa', 'Central Africa', 'West Africa', 'Southern Africa', 'East Africa', 'Middle East', 'Central Asia', 'South Asia', 'SouthEast Asia', 'Far East', 'Australasia', 'Latin America', 'Caribbean', 'Melanesia', 'Micronesia', 'Polynesia']
}

# %%
import csv

country_region_map = {
    'North America': ['USA/Canada'],
    'Western Europe': ['Western Europe', 'Southern Europe', 'Northern Europe'],
    'Eastern Europe': ['Eastern Europe', 'Balkans', 'Transcaucasia'],
    'Middle East and Africa': ['North Africa', 'Central Africa', 'West Africa', 'Southern Africa', 'East Africa', 'Middle East'],
    'Asia Pacific': ['Central Asia', 'South Asia', 'SouthEast Asia', 'Far East', 'Australasia', 'Melanesia', 'Micronesia', 'Polynesia'],
    'Latin America': ['Latin America', 'Caribbean'],
    'World': ['USA/Canada', 'Western Europe', 'Southern Europe', 'Northern Europe', 'Eastern Europe', 'Balkans', 'Transcaucasia', 'North Africa', 'Central Africa', 'West Africa', 'Southern Africa', 'East Africa', 'Middle East', 'Central Asia', 'South Asia', 'SouthEast Asia', 'Far East', 'Australasia', 'Latin America', 'Caribbean', 'Melanesia', 'Micronesia', 'Polynesia']
}

# Write dictionary to csv
with open('./Data/region_map.csv', 'w', newline='') as csvfile:
    fieldnames = ['Region', 'Subregion']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    writer.writeheader()
    for region, subregions in country_region_map.items():
        for subregion in subregions:
            writer.writerow({'Region': region, 'Subregion': subregion})

# %%
country_region_map = {
    'North America': ['USA/Canada'],
    'Western Europe': ['Western Europe', 'Southern Europe', 'Northern Europe'],
    'Eastern Europe': ['Eastern Europe', 'Balkans', 'Transcaucasia'],
    'Middle East and Africa': ['North Africa', 'Central Africa', 'West Africa', 'Southern Africa', 'East Africa', 'Middle East'],
    'Asia Pacific': ['Central Asia', 'South Asia', 'SouthEast Asia', 'Far East', 'Australasia', 'Melanesia', 'Micronesia', 'Polynesia'],
    'Latin America': ['Latin America', 'Caribbean'],
    'World': ['USA/Canada', 'Western Europe', 'Southern Europe', 'Northern Europe', 'Eastern Europe', 'Balkans', 'Transcaucasia', 'North Africa', 'Central Africa', 'West Africa', 'Southern Africa', 'East Africa', 'Middle East', 'Central Asia', 'South Asia', 'SouthEast Asia', 'Far East', 'Australasia', 'Latin America', 'Caribbean', 'Melanesia', 'Micronesia', 'Polynesia']
}

region_id_map = {region: id for id, region in enumerate(country_region_map.keys(), 1)}

with open('./clean_data/region_map.csv', 'w', newline='') as csvfile:
    fieldnames = ['ID', 'Region', 'Subregion']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    writer.writeheader()
    for region, subregions in country_region_map.items():
        for subregion in subregions:
            writer.writerow({'ID': region_id_map[region], 'Region': region, 'Subregion': subregion})

# %%
import csv

data = [
    [1,"Asia Pacific","China"],
    [2,"Asia Pacific","India"],
    [3,"Asia Pacific","Japan"],
    [4,"Asia Pacific","South Korea"],
    [5,"Asia Pacific","Indonesia"],
    [6,"Asia Pacific","Thailand"],
    [7,"Asia Pacific","Vietnam"],
    [8,"Asia Pacific","Malaysia"],
    [9,"Asia Pacific","Singapore"],
    [10,"Asia Pacific","Philippines"],
    [11,"Australasia","Australia"],
    [12,"Australasia","New Zealand"],
    [13,"Eastern Europe","Russia"],
    [14,"Eastern Europe","Poland"],
    [15,"Eastern Europe","Ukraine"],
    [16,"Eastern Europe","Hungary"],
    [17,"Eastern Europe","Czech Republic"],
    [18,"Eastern Europe","Romania"],
    [19,"Eastern Europe","Bulgaria"],
    [20,"Latin America","Brazil"],
    [21,"Latin America","Mexico"],
    [22,"Latin America","Argentina"],
    [23,"Latin America","Chile"],
    [24,"Latin America","Colombia"],
    [25,"Latin America","Peru"],
    [26,"Latin America","Venezuela"],
    [27,"Middle East and Africa","Saudi Arabia"],
    [28,"Middle East and Africa","South Africa"],
    [29,"Middle East and Africa","Egypt"],
    [30,"Middle East and Africa","Iran"],
    [31,"Middle East and Africa","Nigeria"],
    [32,"Middle East and Africa","Turkey"],
    [33,"Middle East and Africa","Israel"],
    [34,"North America","United States"],
    [35,"North America","Canada"],
    [36,"Western Europe","Germany"],
    [37,"Western Europe","France"],
    [38,"Western Europe","United Kingdom"],
    [39,"Western Europe","Italy"],
    [40,"Western Europe","Spain"],
    [41,"Western Europe","Netherlands"],
    [42,"Western Europe","Switzerland"],
    [43,"Western Europe","Belgium"],
    [44,"Western Europe","Austria"],
    [45,"Western Europe","Sweden"],
]


filename = "./clean_data/extra/regionstest.csv"
with open(filename, 'w') as csvfile:
    
    csvwriter = csv.writer(csvfile)
    csvwriter.writerow(["id", "Region", "Country"])
    csvwriter.writerows(data)

# %%
import csv

data = [
    [1,"Asia Pacific","China"],
    [2,"Asia Pacific","India"],
    [3,"Asia Pacific","Japan"],
    [4,"Asia Pacific","South Korea"],
    [5,"Asia Pacific","Indonesia"],
    [6,"Asia Pacific","Thailand"],
    [7,"Asia Pacific","Vietnam"],
    [8,"Asia Pacific","Malaysia"],
    [9,"Asia Pacific","Singapore"],
    [10,"Asia Pacific","Philippines"],
    [11,"Asia Pacific","Cambodia"],
    [12,"Asia Pacific","Myanmar"],
    [13,"Asia Pacific","Laos"],
    [14,"Asia Pacific","Bangladesh"],
    [15,"Asia Pacific","Pakistan"],
    [16,"Asia Pacific","Nepal"],
    [17,"Asia Pacific","Bhutan"],
    [18,"Asia Pacific","Mongolia"],
    [19,"Asia Pacific","Sri Lanka"],
    [20,"Australasia","Australia"],
    [21,"Australasia","New Zealand"],
    [22,"Australasia","Papua New Guinea"],
    [23,"Australasia","Fiji"],
    [24,"Australasia","Solomon Islands"],
    [25,"Eastern Europe","Russia"],
    [26,"Eastern Europe","Poland"],
    [27,"Eastern Europe","Ukraine"],
    [28,"Eastern Europe","Hungary"],
    [29,"Eastern Europe","Czech Republic"],
    [30,"Eastern Europe","Romania"],
    [31,"Eastern Europe","Bulgaria"],
    [32,"Latin America","Brazil"],
    [33,"Latin America","Mexico"],
    [34,"Latin America","Argentina"],
    [35,"Latin America","Chile"],
    [36,"Latin America","Colombia"],
    [37,"Latin America","Peru"],
    [38,"Latin America","Venezuela"],
    [39,"Latin America","Ecuador"],
    [40,"Latin America","Bolivia"],
    [41,"Latin America","Paraguay"],
    [42,"Latin America","Uruguay"],
    [43,"Latin America","Costa Rica"],
    [44,"Latin America","Cuba"],
    [45,"Latin America","Guatemala"],
    [46,"Latin America","Honduras"],
    [47,"Latin America","Nicaragua"],
    [48,"Latin America","Panama"],
    [49,"Latin America","El Salvador"],
    [50,"Latin America","Dominican Republic"],
    [51,"Middle East and Africa","Algeria"],
    [52,"Middle East and Africa","Angola"],
    [53,"Middle East and Africa","Benin"],
    [54,"Middle East and Africa","Botswana"],
    [55,"Middle East and Africa","Burkina Faso"],
    [56,"Middle East and Africa","Burundi"],
    [57,"Middle East and Africa","Côte d'Ivoire"],
    [58,"Middle East and Africa","Cameroon"],
    [59,"Middle East and Africa","Cape Verde"],
    [60,"Middle East and Africa","Central African Republic"],
    [61,"Middle East and Africa","Chad"],
    [62,"Middle East and Africa","Comoros"],
    [63,"Middle East and Africa","Congo (Brazzaville)"],
    [64,"Middle East and Africa","Congo (Kinshasa)"],
    [65,"Middle East and Africa","Djibouti"],
    [66,"Middle East and Africa","Egypt"],
    [67,"Middle East and Africa","Equatorial Guinea"],
    [68,"Middle East and Africa","Eritrea"],
    [69,"Middle East and Africa","Eswatini"],
    [70,"Middle East and Africa","Ethiopia"],
    [71,"Middle East and Africa","Gabon"],
    [72,"Middle East and Africa","Gambia"],
    [73,"Middle East and Africa","Ghana"],
    [74,"Middle East and Africa","Guinea"],
    [75,"Middle East and Africa","Guinea-Bissau"],
    [76,"Middle East and Africa","Iran"],
    [77,"Middle East and Africa","Israel"],
    [78,"Middle East and Africa","Kenya"],
    [79,"Middle East and Africa","Lesotho"],
    [80,"Middle East and Africa","Liberia"],
    [81,"Middle East and Africa","Libya"],
    [82,"Middle East and Africa","Madagascar"],
    [83,"Middle East and Africa","Malawi"],
    [84,"Middle East and Africa","Mali"],
    [85,"Middle East and Africa","Mauritania"],
    [86,"Middle East and Africa","Mauritius"],
    [87,"Middle East and Africa","Morocco"],
    [88,"Middle East and Africa","Mozambique"],
    [89,"Middle East and Africa","Namibia"],
    [90,"Middle East and Africa","Niger"],
    [91,"Middle East and Africa","Nigeria"],
    [92,"Middle East and Africa","Rwanda"],
    [93,"Middle East and Africa","São Tomé and Príncipe"],
    [94,"Middle East and Africa","Saudi Arabia"],
    [95,"Middle East and Africa","Senegal"],
    [96,"Middle East and Africa","Seychelles"],
    [97,"Middle East and Africa","Sierra Leone"],
    [98,"Middle East and Africa","Somalia"],
    [99,"Middle East and Africa","South Africa"],
    [100,"Middle East and Africa","South Sudan"],
    [101,"Middle East and Africa","Sudan"],
    [102,"Middle East and Africa","Tanzania"],
    [103,"Middle East and Africa","Togo"],
    [104,"Middle East and Africa","Tunisia"],
    [105,"Middle East and Africa","Turkey"],
    [106,"North America","United States"],
    [107,"North America","Canada"],
    [108,"Western Europe","Germany"],
    [109,"Western Europe","France"],
    [110,"Western Europe","United Kingdom"],
    [111,"Western Europe","Italy"],
    [112,"Western Europe","Spain"],
    [113,"Western Europe","Netherlands"],
    [114,"Western Europe","Switzerland"],
    [115,"Western Europe","Belgium"],
    [116,"Western Europe","Austria"],
    [117,"Western Europe","Sweden"],
    [118,"Western Europe","Denmark"],
    [119,"Western Europe","Norway"],
    [120,"Western Europe","Ireland"],
    [121,"Western Europe","Portugal"],
    [122,"Western Europe","Finland"],
    [123,"Western Europe","Greece"],
    [124,"Western Europe","Iceland"],
    [125,"Western Europe","Luxembourg"],
    [126,"Western Europe","Malta"],
]

filename = "./clean_data/regionstest.csv"

with open(filename, 'w') as csvfile:
    csvwriter = csv.writer(csvfile)
    csvwriter.writerow(["id", "Region", "Country"])
    csvwriter.writerows(data)

# %%
import csv

data = [
    [1,"Asia Pacific","China"],
    [2,"Asia Pacific","India"],
    [3,"Asia Pacific","Japan"],
    [4,"Asia Pacific","South Korea"],
    [5,"Asia Pacific","Indonesia"],
    [6,"Asia Pacific","Thailand"],
    [7,"Asia Pacific","Vietnam"],
    [8,"Asia Pacific","Malaysia"],
    [9,"Asia Pacific","Singapore"],
    [10,"Asia Pacific","Philippines"],
    [11,"Asia Pacific","Cambodia"],
    [12,"Asia Pacific","Myanmar"],
    [13,"Asia Pacific","Laos"],
    [14,"Asia Pacific","Bangladesh"],
    [15,"Asia Pacific","Pakistan"],
    [16,"Asia Pacific","Nepal"],
    [17,"Asia Pacific","Bhutan"],
    [18,"Asia Pacific","Mongolia"],
    [19,"Asia Pacific","Sri Lanka"],
    [20,"Australasia","Australia"],
    [21,"Australasia","New Zealand"],
    [22,"Australasia","Papua New Guinea"],
    [23,"Australasia","Fiji"],
    [24,"Australasia","Solomon Islands"],
    [25,"Eastern Europe","Russia"],
    [26,"Eastern Europe","Poland"],
    [27,"Eastern Europe","Ukraine"],
    [28,"Eastern Europe","Hungary"],
    [29,"Eastern Europe","Czech Republic"],
    [30,"Eastern Europe","Romania"],
    [31,"Eastern Europe","Bulgaria"],
    [32,"Latin America","Brazil"],
    [33,"Latin America","Mexico"],
    [34,"Latin America","Argentina"],
    [35,"Latin America","Chile"],
    [36,"Latin America","Colombia"],
    [37,"Latin America","Peru"],
    [38,"Latin America","Venezuela"],
    [39,"Latin America","Ecuador"],
    [40,"Latin America","Bolivia"],
    [41,"Latin America","Paraguay"],
    [42,"Latin America","Uruguay"],
    [43,"Latin America","Costa Rica"],
    [44,"Latin America","Cuba"],
    [45,"Latin America","Guatemala"],
    [46,"Latin America","Honduras"],
    [47,"Latin America","Nicaragua"],
    [48,"Latin America","Panama"],
    [49,"Latin America","El Salvador"],
    [50,"Latin America","Dominican Republic"],
    [51,"Middle East and Africa","Algeria"],
    [52,"Middle East and Africa","Angola"],
    [53,"Middle East and Africa","Benin"],
    [54,"Middle East and Africa","Botswana"],
    [55,"Middle East and Africa","Burkina Faso"],
    [56,"Middle East and Africa","Burundi"],
    [57,"Middle East and Africa","Côte d'Ivoire"],
    [58,"Middle East and Africa","Cameroon"],
    [59,"Middle East and Africa","Cape Verde"],
    [60,"Middle East and Africa","Central African Republic"],
    [61,"Middle East and Africa","Chad"],
    [62,"Middle East and Africa","Comoros"],
    [63,"Middle East and Africa","Congo (Brazzaville)"],
    [64,"Middle East and Africa","Congo (Kinshasa)"],
    [65,"Middle East and Africa","Djibouti"],
    [66,"Middle East and Africa","Egypt"],
    [67,"Middle East and Africa","Equatorial Guinea"],
    [68,"Middle East and Africa","Eritrea"],
    [69,"Middle East and Africa","Eswatini"],
    [70,"Middle East and Africa","Ethiopia"],
    [71,"Middle East and Africa","Gabon"],
    [72,"Middle East and Africa","Gambia"],
    [73,"Middle East and Africa","Ghana"],
    [74,"Middle East and Africa","Guinea"],
    [75,"Middle East and Africa","Guinea-Bissau"],
    [76,"Middle East and Africa","Iran"],
    [77,"Middle East and Africa","Israel"],
    [78,"Middle East and Africa","Kenya"],
    [79,"Middle East and Africa","Lesotho"],
    [80,"Middle East and Africa","Liberia"],
    [81,"Middle East and Africa","Libya"],
    [82,"Middle East and Africa","Madagascar"],
    [83,"Middle East and Africa","Malawi"],
    [84,"Middle East and Africa","Mali"],
    [85,"Middle East and Africa","Mauritania"],
    [86,"Middle East and Africa","Mauritius"],
    [87,"Middle East and Africa","Morocco"],
    [88,"Middle East and Africa","Mozambique"],
    [89,"Middle East and Africa","Namibia"],
    [90,"Middle East and Africa","Niger"],
    [91,"Middle East and Africa","Nigeria"],
    [92,"Middle East and Africa","Rwanda"],
    [93,"Middle East and Africa","São Tomé and Príncipe"],
    [94,"Middle East and Africa","Saudi Arabia"],
    [95,"Middle East and Africa","Senegal"],
    [96,"Middle East and Africa","Seychelles"],
    [97,"Middle East and Africa","Sierra Leone"],
    [98,"Middle East and Africa","Somalia"],
    [99,"Middle East and Africa","South Africa"],
    [100,"Middle East and Africa","South Sudan"],
    [101,"Middle East and Africa","Sudan"],
    [102,"Middle East and Africa","Tanzania"],
    [103,"Middle East and Africa","Togo"],
    [104,"Middle East and Africa","Tunisia"],
    [105,"Middle East and Africa","Turkey"],
    [106,"North America","United States"],
    [107,"North America","Canada"],
    [108,"Western Europe","Germany"],
    [109,"Western Europe","France"],
    [110,"Western Europe","United Kingdom"],
    [111,"Western Europe","Italy"],
    [112,"Western Europe","Spain"],
    [113,"Western Europe","Netherlands"],
    [114,"Western Europe","Switzerland"],
    [115,"Western Europe","Belgium"],
    [116,"Western Europe","Austria"],
    [117,"Western Europe","Sweden"],
    [118,"Western Europe","Denmark"],
    [119,"Western Europe","Norway"],
    [120,"Western Europe","Ireland"],
    [121,"Western Europe","Portugal"],
    [122,"Western Europe","Finland"],
    [123,"Western Europe","Greece"],
    [124,"Western Europe","Iceland"],
    [125,"Western Europe","Luxembourg"],
    [126,"Western Europe","Malta"],
    [127,"Middle East and Africa","Western Sahara"],
    [128,"Middle East and Africa","Uganda"],
    [129,"Middle East and Africa","Zambia"],
    [130,"Middle East and Africa","Zimbabwe"],
    [131,"Latin America","Guyana"],
    [132,"Latin America","Suriname"],
    [133,"Latin America","French Guiana"],
    [134,"Middle East and Africa","Syria"],
    [135,"Middle East and Africa","Iraq"],
    [136,"Middle East and Africa","Jordan"],
    [137,"Eastern Europe","Georgia"],
    [138,"Eastern Europe","Estonia"],
    [139,"Eastern Europe","Latvia"],
    [140,"Eastern Europe","Lithuania"],
    [141,"Eastern Europe","Belarus"],
    [142,"Eastern Europe","Slovakia"],
    [143,"Eastern Europe","Moldova"],
    [144,"Eastern Europe","Serbia"],
    [145,"Eastern Europe","Kosovo"],
    [146,"Eastern Europe","North Macedonia"],
    [147,"Eastern Europe","Albania"],
    [148,"Eastern Europe","Croatia"],
    [149,"Western Europe","Slovenia"],
    [150,"Eastern Europe","Bosnia and Herzegovina"],
    [151,"Asia Pacific","Kazakhstan"],
    [152,"Asia Pacific","Uzbekistan"],
    [153,"Asia Pacific","Kyrgyzstan"],
    [154,"Asia Pacific","Tajikistan"],
    [155,"Asia Pacific","Afghanistan"],
    [156,"Asia Pacific","Turkmenistan"],
    [157,"Asia Pacific","Azerbaijan"],
    [158,"Asia Pacific","Armenia"],
    [159,"Eastern Europe","Montenegro"]
]

filename = "./clean_data/regionstest.csv"
with open(filename, 'w', newline='') as csvfile:
    csvwriter = csv.writer(csvfile)
    csvwriter.writerow(["ID","Region","Country"])
    csvwriter.writerows(data)
